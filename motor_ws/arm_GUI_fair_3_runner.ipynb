# %% [markdown]
# # Arm GUI fair 3 runner
#
# This notebook launches the Micro-ROS Agent and the GUI in separate terminals using the helper script.
#
# Prereqs:
# - ROS 2 Humble is installed at `/opt/ros/humble`.
# - Micro-ROS workspace exists at `~/microros_ws`.
# - Boxing robot workspace exists at `~/boxing_robot`.
#
# If you have a different setup, edit `run_arm_gui_fair_3_all.sh` first.

# %%
# !bash /home/boxbunny/boxing_robot/run_arm_gui_fair_3_all.sh

# %% [markdown]
# If you prefer manual terminal commands, see the same script for the exact steps.
