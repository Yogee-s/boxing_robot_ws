# %% [markdown]
# # BoxBunny ROS 2 Commands (Runnable)
# Use these cells to build and launch specific subsystems without rebuilding everything.

# %% [markdown]
# ## Build workspace (all packages)

# %%
# !source /opt/ros/humble/setup.bash && \
  cd /home/boxbunny/Desktop/doomsday_integration/boxing_robot_ws && \
  colcon build --symlink-install

# %% [markdown]
# ## Full system launch

# %%
# !source /opt/ros/humble/setup.bash && \
  cd /home/boxbunny/Desktop/doomsday_integration/boxing_robot_ws && \
  source install/setup.bash && \
  ros2 launch boxbunny_bringup boxbunny_system.launch.py enable_imu:=true enable_llm:=true enable_gui:=true

# %% [markdown]
# ## Vision-only (camera + glove tracker)

# %%
# !source /opt/ros/humble/setup.bash && \
  cd /home/boxbunny/Desktop/doomsday_integration/boxing_robot_ws && \
  colcon build --symlink-install --packages-select boxbunny_vision && \
  source install/setup.bash && \
  ros2 launch boxbunny_bringup vision_only.launch.py

# %% [markdown]
# ## IMU-only (MPU6050 + classifier)

# %%
# !source /opt/ros/humble/setup.bash && \
  cd /home/boxbunny/Desktop/doomsday_integration/boxing_robot_ws && \
  colcon build --symlink-install --packages-select boxbunny_imu && \
  source install/setup.bash && \
  ros2 launch boxbunny_bringup imu_only.launch.py enable_classifier:=true

# %% [markdown]
# ## GUI-only (layout preview)

# %%
# !source /opt/ros/humble/setup.bash && \
  cd /home/boxbunny/Desktop/doomsday_integration/boxing_robot_ws && \
  colcon build --symlink-install --packages-select boxbunny_gui && \
  source install/setup.bash && \
  ros2 launch boxbunny_bringup gui_only.launch.py

# %% [markdown]
# ## LLM node only (ROS)

# %%
# !source /opt/ros/humble/setup.bash && \
  cd /home/boxbunny/Desktop/doomsday_integration/boxing_robot_ws && \
  colcon build --symlink-install --packages-select boxbunny_llm && \
  source install/setup.bash && \
  ros2 launch boxbunny_bringup llm_only.launch.py

# %% [markdown]
# ## LLM Chat GUI (for tuning + prompt editing)

# %%
# !source /opt/ros/humble/setup.bash && \
  cd /home/boxbunny/Desktop/doomsday_integration/boxing_robot_ws && \
  colcon build --symlink-install --packages-select boxbunny_llm && \
  source install/setup.bash && \
  ros2 run boxbunny_llm llm_chat_gui

# %% [markdown]
# ## IMU Punch GUI (live data + calibration)
# Start the IMU nodes (IMU-only launch) first, then run this GUI.

# %%
# !source /opt/ros/humble/setup.bash && \
  cd /home/boxbunny/Desktop/doomsday_integration/boxing_robot_ws && \
  colcon build --symlink-install --packages-select boxbunny_imu && \
  source install/setup.bash && \
  ros2 run boxbunny_imu imu_punch_gui
